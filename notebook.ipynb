# %% [markdown]
# ## AirBnb Rio

# %% [markdown]
# Installing libs

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.figure_factory as ff
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
# %matplotlib inline

# %% [markdown]
# Reading data

# %%
df = pd.read_csv('./listings.csv')
df.head()
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0  17878  https://www.airbnb.com/rooms/17878  20210321015201   2021-03-25
# 1  24480  https://www.airbnb.com/rooms/24480  20210321015201   2021-03-22
# 2  35636  https://www.airbnb.com/rooms/35636  20210321015201   2021-03-25
# 3  35764  https://www.airbnb.com/rooms/35764  20210321015201   2021-03-25
# 4  41198  https://www.airbnb.com/rooms/41198  20210321015201   2021-03-22
#
#                                                 name  \
# 0  Very Nice 2Br in Copacabana w. balcony, fast WiFi
# 1                   Nice and cozy near Ipanema Beach
# 2                   Cosy flat close to Ipanema beach
# 3     COPACABANA SEA BREEZE  -  RIO - 20 X Superhost
# 4                  Modern 2bed,Top end of Copacabana
#
#                                          description  \
# 0  Discounts for long term stays. <br />- Large b...
# 1  My studio is located in the best  of Ipanema. ...
# 2  This cosy apartment  is just a few steps away ...
# 3  Our newly renovated studio is located in the b...
# 4  <b>The space</b><br />Stay in this, Modern,cle...
#
#                                neighborhood_overview  \
# 0  This is the one of the bests spots in Rio. Bec...
# 1  The beach, the lagoon, Ipanema is a great loca...
# 2  The  apartment street is very quiet and safe ....
# 3  Our guests will experience living with a local...
# 4                                                NaN
#
#                                          picture_url  host_id  \
# 0  https://a0.muscache.com/pictures/65320518/3069...    68997
# 1  https://a0.muscache.com/pictures/11955612/b28e...    99249
# 2  https://a0.muscache.com/pictures/20009355/38b6...   153232
# 3  https://a0.muscache.com/pictures/23782972/1d3e...   153691
# 4  https://a0.muscache.com/pictures/3576716/2d6a9...   178975
#
#                                    host_url  ... review_scores_communication  \
# 0   https://www.airbnb.com/users/show/68997  ...                        10.0
# 1   https://www.airbnb.com/users/show/99249  ...                        10.0
# 2  https://www.airbnb.com/users/show/153232  ...                        10.0
# 3  https://www.airbnb.com/users/show/153691  ...                        10.0
# 4  https://www.airbnb.com/users/show/178975  ...                         9.0
#
#   review_scores_location review_scores_value license instant_bookable  \
# 0                   10.0                 9.0     NaN                t
# 1                   10.0                 9.0     NaN                f
# 2                   10.0                 9.0     NaN                f
# 3                   10.0                10.0     NaN                f
# 4                    9.0                 9.0     NaN                f
#
#   calculated_host_listings_count calculated_host_listings_count_entire_homes  \
# 0                              1                                           1
# 1                              1                                           1
# 2                              1                                           1
# 3                              1                                           1
# 4                              2                                           2
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            0
# 1                                            0
# 2                                            0
# 3                                            0
# 4                                            0
#
#   calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                           0              2.00
# 1                                           0              0.67
# 2                                           0              2.00
# 3                                           0              2.79
# 4                                           0              0.18
#
# [5 rows x 74 columns]

# %% [markdown]
# ### Neighbourhood Overview

# %% [markdown]
# #### What neighbourhoods have the biggest number of properties?

# %% [markdown]
# First, we will analyze the number of properties in each neighbourhood.

# %%
fig = px.bar((df.neighbourhood_cleansed.value_counts().nlargest(10)/df.shape[0]), 
             orientation='h', 
             title="Top 10 neighbourhoods by number of properties",
            template='simple_white')
fig.update_yaxes(categoryorder='total ascending')
fig.update_layout(showlegend=False)
# Out:
# <div>                            <div id="75dad27c-265e-42d2-b67b-c442a6613362" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("75dad27c-265e-42d2-b67b-c442a6613362")) {                    Plotly.newPlot(                        "75dad27c-265e-42d2-b67b-c442a6613362",                        [{"alignmentgroup": "True", "hovertemplate": "variable=neighbourhood_cleansed<br>value=%{x}<br>index=%{y}<extra></extra>", "legendgroup": "neighbourhood_cleansed", "marker": {"color": "#1F77B4"}, "name": "neighbourhood_cleansed", "offsetgroup": "neighbourhood_cleansed", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [0.28898152320865256, 0.1017725702268289, 0.09692804566621602, 0.050698512843623256, 0.0452155625657203, 0.044539582394471984, 0.04442691903259727, 0.03323569175304191, 0.02921736517951029, 0.023509088177857893], "xaxis": "x", "y": ["Copacabana", "Barra da Tijuca", "Ipanema", "Jacarepagu\u00e1", "Botafogo", "Recreio dos Bandeirantes", "Leblon", "Santa Teresa", "Centro", "Flamengo"], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"title": {"text": "variable"}, "tracegroupgap": 0}, "showlegend": false, "template": {"data": {"bar": [{"error_x": {"color": "rgb(36,36,36)"}, "error_y": {"color": "rgb(36,36,36)"}, "marker": {"line": {"color": "white", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "white", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "rgb(36,36,36)", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "rgb(36,36,36)"}, "baxis": {"endlinecolor": "rgb(36,36,36)", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "rgb(36,36,36)"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 1, "tickcolor": "rgb(36,36,36)", "ticks": "outside"}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 1, "tickcolor": "rgb(36,36,36)", "ticks": "outside"}, "colorscale": [[0.0, "#440154"], [0.1111111111111111, "#482878"], [0.2222222222222222, "#3e4989"], [0.3333333333333333, "#31688e"], [0.4444444444444444, "#26828e"], [0.5555555555555556, "#1f9e89"], [0.6666666666666666, "#35b779"], [0.7777777777777778, "#6ece58"], [0.8888888888888888, "#b5de2b"], [1.0, "#fde725"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 1, "tickcolor": "rgb(36,36,36)", "ticks": "outside"}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 1, "tickcolor": "rgb(36,36,36)", "ticks": "outside"}, "colorscale": [[0.0, "#440154"], [0.1111111111111111, "#482878"], [0.2222222222222222, "#3e4989"], [0.3333333333333333, "#31688e"], [0.4444444444444444, "#26828e"], [0.5555555555555556, "#1f9e89"], [0.6666666666666666, "#35b779"], [0.7777777777777778, "#6ece58"], [0.8888888888888888, "#b5de2b"], [1.0, "#fde725"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 1, "tickcolor": "rgb(36,36,36)", "ticks": "outside"}, "colorscale": [[0.0, "#440154"], [0.1111111111111111, "#482878"], [0.2222222222222222, "#3e4989"], [0.3333333333333333, "#31688e"], [0.4444444444444444, "#26828e"], [0.5555555555555556, "#1f9e89"], [0.6666666666666666, "#35b779"], [0.7777777777777778, "#6ece58"], [0.8888888888888888, "#b5de2b"], [1.0, "#fde725"]], "type": "heatmapgl"}], "histogram": [{"marker": {"line": {"color": "white", "width": 0.6}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 1, "tickcolor": "rgb(36,36,36)", "ticks": "outside"}, "colorscale": [[0.0, "#440154"], [0.1111111111111111, "#482878"], [0.2222222222222222, "#3e4989"], [0.3333333333333333, "#31688e"], [0.4444444444444444, "#26828e"], [0.5555555555555556, "#1f9e89"], [0.6666666666666666, "#35b779"], [0 ...

# %% [markdown]
# Copacabana has almost 30% of the properties in Rio de Janeiro. Barra da Tijuca and Ipanema have 10% each.
# These 3 neighbourhoods represent almost 50% of the properties in Rio.

# %% [markdown]
# #### What are the most expensive neighbourhoods?

# %% [markdown]
# Next, we will analyze the neighbourhoods with the highest prices.

# %%
df['price'].value_counts()
# Out:
# $200.00      908
# $250.00      899
# $150.00      878
# $300.00      797
# $500.00      654
#             ...
# $4,433.00      1
# $901.00        1
# $1,142.00      1
# $706.00        1
# $761.00        1
# Name: price, Length: 1611, dtype: int64

# %%
df['price'].head()
# Out:
# 0    $200.00
# 1    $307.00
# 2    $275.00
# 3    $120.00
# 4    $494.00
# Name: price, dtype: object

# %% [markdown]
# We need to clean and transform the variable 'price' to answer the question

# %%
df['price'] = df['price'].map(lambda p: int(p[1:-3].replace(",", "")))
df['price'].value_counts()
# Out:
# 200     908
# 250     899
# 150     878
# 300     797
# 500     654
#        ...
# 477       1
# 4308      1
# 525       1
# 6670      1
# 2015      1
# Name: price, Length: 1611, dtype: int64

# %% [markdown]
# Now, we can understand the distribution of the variable. The boxplot below shows the outliers.

# %%
fig = px.box(df['price'])
fig.show()
# Out:
# <div>                            <div id="164edca5-cb2f-4f93-b844-d75bd1e83c2e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("164edca5-cb2f-4f93-b844-d75bd1e83c2e")) {                    Plotly.newPlot(                        "164edca5-cb2f-4f93-b844-d75bd1e83c2e",                        [{"alignmentgroup": "True", "hovertemplate": "variable=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "notched": false, "offsetgroup": "", "orientation": "v", "showlegend": false, "type": "box", "x": ["price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "price", "pri ...

# %%
fig = px.box(df, x='neighbourhood_cleansed', y='price')
fig.update_yaxes(categoryorder='total descending')
fig.show()
# Out:
# <div>                            <div id="56cb8cba-0c4a-4944-8ad9-8d2ebb40b29b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("56cb8cba-0c4a-4944-8ad9-8d2ebb40b29b")) {                    Plotly.newPlot(                        "56cb8cba-0c4a-4944-8ad9-8d2ebb40b29b",                        [{"alignmentgroup": "True", "hovertemplate": "neighbourhood_cleansed=%{x}<br>price=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "notched": false, "offsetgroup": "", "orientation": "v", "showlegend": false, "type": "box", "x": ["Copacabana", "Ipanema", "Ipanema", "Copacabana", "Copacabana", "Ipanema", "Ipanema", "Copacabana", "Copacabana", "Ipanema", "Barra da Tijuca", "Copacabana", "Ipanema", "Ipanema", "Flamengo", "Ipanema", "Copacabana", "Ipanema", "Copacabana", "Copacabana", "Copacabana", "Santa Teresa", "Santa Teresa", "G\u00e1vea", "Santa Teresa", "Copacabana", "Leblon", "Jacarepagu\u00e1", "Campo Grande", "Ipanema", "Copacabana", "Copacabana", "Leblon", "Copacabana", "Laranjeiras", "Ipanema", "Copacabana", "Humait\u00e1", "S\u00e3o Conrado", "S\u00e3o Conrado", "Copacabana", "Barra da Tijuca", "Botafogo", "Botafogo", "Centro", "Vidigal", "Botafogo", "Santo Cristo", "Barra da Tijuca", "Santa Teresa", "Copacabana", "Santa Teresa", "Ipanema", "Itanhang\u00e1", "S\u00e3o Crist\u00f3v\u00e3o", "Copacabana", "G\u00e1vea", "Copacabana", "Laranjeiras", "Copacabana", "Maracan\u00e3", "Gl\u00f3ria", "Leblon", "Leblon", "Lagoa", "Ipanema", "Botafogo", "S\u00e3o Francisco Xavier", "Catete", "Humait\u00e1", "Jacarepagu\u00e1", "Copacabana", "Copacabana", "Copacabana", "Ipanema", "Copacabana", "Copacabana", "Vidigal", "Copacabana", "Copacabana", "Copacabana", "Copacabana", "Copacabana", "Copacabana", "Centro", "Santa Teresa", "Santa Teresa", "Copacabana", "Botafogo", "Ipanema", "Humait\u00e1", "Ipanema", "Ipanema", "Copacabana", "Marechal Hermes", "Jardim Bot\u00e2nico", "Laranjeiras", "Copacabana", "Copacabana", "Ipanema", "Gl\u00f3ria", "Copacabana", "Copacabana", "Copacabana", "Copacabana", "Flamengo", "Laranjeiras", "Santa Teresa", "Tijuca", "Copacabana", "Copacabana", "Ipanema", "Flamengo", "Copacabana", "Jacarepagu\u00e1", "Copacabana", "Copacabana", "Copacabana", "Copacabana", "Copacabana", "Botafogo", "Copacabana", "Botafogo", "Ipanema", "Copacabana", "Copacabana", "Barra da Tijuca", "Copacabana", "Vidigal", "Copacabana", "Santa Teresa", "Barra da Tijuca", "Botafogo", "Barra da Tijuca", "Copacabana", "Copacabana", "Vidigal", "Copacabana", "Copacabana", "Leblon", "Jardim Bot\u00e2nico", "Santa Teresa", "Lagoa", "Leblon", "Santa Teresa", "Santa Teresa", "Santa Teresa", "Ipanema", "S\u00e3o Conrado", "Ipanema", "Copacabana", "Lagoa", "Botafogo", "Centro", "Lagoa", "Flamengo", "Ipanema", "Copacabana", "Copacabana", "Centro", "Copacabana", "Copacabana", "Copacabana", "Copacabana", "Copacabana", "Copacabana", "Copacabana", "Copacabana", "Copacabana", "Santa Teresa", "Santa Teresa", "Copacabana", "Laranjeiras", "Laranjeiras", "Santa Teresa", "Santa Teresa", "Copacabana", "Ipanema", "Copacabana", "Copacabana", "Ipanema", "Senador Camar\u00e1", "Iraj\u00e1", "Leblon", "Ipanema", "Ipanema", "G\u00e1vea", "Botafogo", "Copacabana", "Botafogo", "Botafogo", "Santa Teresa", "Santa Teresa", "Ipanema", "Ipanema", "Copacabana", "Botafogo", "Botafogo", "Vargem Grande", "Copacabana", "Copacabana", "Santa Teresa", "Santa Teresa", "Santa Teresa", "Vargem Grande", "Jardim Bot\u00e2nico", "Recreio dos Bandeirantes", "Lagoa", "Botafogo", "Santa Teresa", "Santa Teresa", "Gl\u00f3ria", "Copacabana", "Botafogo", "Centro", "Barra da Tijuca", "Barra da Tijuca", "Iraj\u00e1", "Copacabana", "Botafogo", "Copacabana", "Copacabana", "Flamengo", "Copacabana", "Copacabana", "Humait\u00e1", "Ipanema", "Ip ...

# %% [markdown]
# We will use the median so that the outliers have a smaller effect.

# %%
fig = px.bar(df.groupby('neighbourhood_cleansed').median()['price'].nlargest(10), 
             orientation='h', 
             title="Top 10 neighbourhoods by highest prices",
            template='simple_white')
fig.update_yaxes(categoryorder='total ascending')
fig.update_layout(showlegend=False)
# Out:
# <div>                            <div id="63286611-2fc8-45e8-8061-657f143e9cbe" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("63286611-2fc8-45e8-8061-657f143e9cbe")) {                    Plotly.newPlot(                        "63286611-2fc8-45e8-8061-657f143e9cbe",                        [{"alignmentgroup": "True", "hovertemplate": "variable=price<br>value=%{x}<br>neighbourhood_cleansed=%{y}<extra></extra>", "legendgroup": "price", "marker": {"color": "#1F77B4"}, "name": "price", "offsetgroup": "price", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [2277.5, 1309.0, 1000.0, 925.0, 900.0, 838.5, 800.0, 761.5, 700.0, 661.0], "xaxis": "x", "y": ["Jo\u00e1", "Vista Alegre", "Realengo", "Cavalcanti", "Osvaldo Cruz", "Vaz Lobo", "Anchieta", "Freguesia (Ilha)", "Alto da Boa Vista", "Grumari"], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"title": {"text": "variable"}, "tracegroupgap": 0}, "showlegend": false, "template": {"data": {"bar": [{"error_x": {"color": "rgb(36,36,36)"}, "error_y": {"color": "rgb(36,36,36)"}, "marker": {"line": {"color": "white", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "white", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "rgb(36,36,36)", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "rgb(36,36,36)"}, "baxis": {"endlinecolor": "rgb(36,36,36)", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "rgb(36,36,36)"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 1, "tickcolor": "rgb(36,36,36)", "ticks": "outside"}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 1, "tickcolor": "rgb(36,36,36)", "ticks": "outside"}, "colorscale": [[0.0, "#440154"], [0.1111111111111111, "#482878"], [0.2222222222222222, "#3e4989"], [0.3333333333333333, "#31688e"], [0.4444444444444444, "#26828e"], [0.5555555555555556, "#1f9e89"], [0.6666666666666666, "#35b779"], [0.7777777777777778, "#6ece58"], [0.8888888888888888, "#b5de2b"], [1.0, "#fde725"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 1, "tickcolor": "rgb(36,36,36)", "ticks": "outside"}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 1, "tickcolor": "rgb(36,36,36)", "ticks": "outside"}, "colorscale": [[0.0, "#440154"], [0.1111111111111111, "#482878"], [0.2222222222222222, "#3e4989"], [0.3333333333333333, "#31688e"], [0.4444444444444444, "#26828e"], [0.5555555555555556, "#1f9e89"], [0.6666666666666666, "#35b779"], [0.7777777777777778, "#6ece58"], [0.8888888888888888, "#b5de2b"], [1.0, "#fde725"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 1, "tickcolor": "rgb(36,36,36)", "ticks": "outside"}, "colorscale": [[0.0, "#440154"], [0.1111111111111111, "#482878"], [0.2222222222222222, "#3e4989"], [0.3333333333333333, "#31688e"], [0.4444444444444444, "#26828e"], [0.5555555555555556, "#1f9e89"], [0.6666666666666666, "#35b779"], [0.7777777777777778, "#6ece58"], [0.8888888888888888, "#b5de2b"], [1.0, "#fde725"]], "type": "heatmapgl"}], "histogram": [{"marker": {"line": {"color": "white", "width": 0.6}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 1, "tickcolor": "rgb(36,36,36)", "ticks": "outside"}, "colorscale": [[0.0, "#440154"], [0.1111111111111111, "#482878"], [0.2222222222222222, "#3e4989"], [0.3333333333333333, "#31688e"], [0.4444444444444444, "#26828e"], [0.5555555555555556, "#1f9e89"], [0.6666666666666666, "#35b779"], [0.7777777777777778, "#6ece58"], [0.8888888888888888, "#b5de2b"], [1.0, "#fde725"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 1, "tickcolor": "rgb(36,36,36)", " ...

# %% [markdown]
# Still, we will treat these outliers. The histogram below shows the distribution and the upper limit and lower limit used, also based on the boxplot seen before.

# %%
fig = px.histogram(df[(df.price<1114)]['price'])
fig.show()
# Out:
# <div>                            <div id="a7301f9d-02ef-447e-87e5-a0d95379c20e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a7301f9d-02ef-447e-87e5-a0d95379c20e")) {                    Plotly.newPlot(                        "a7301f9d-02ef-447e-87e5-a0d95379c20e",                        [{"alignmentgroup": "True", "bingroup": "x", "hovertemplate": "variable=price<br>value=%{x}<br>count=%{y}<extra></extra>", "legendgroup": "price", "marker": {"color": "#636efa"}, "name": "price", "offsetgroup": "price", "orientation": "v", "showlegend": true, "type": "histogram", "x": [200, 307, 275, 120, 494, 110, 540, 150, 140, 333, 180, 145, 215, 230, 183, 401, 784, 65, 100, 194, 110, 163, 264, 826, 146, 100, 179, 157, 390, 224, 496, 329, 197, 190, 150, 110, 180, 257, 170, 128, 144, 393, 200, 386, 650, 54, 165, 261, 682, 826, 321, 140, 180, 105, 160, 300, 120, 792, 180, 384, 881, 200, 1101, 275, 250, 130, 249, 170, 161, 141, 136, 439, 109, 600, 125, 111, 661, 150, 214, 279, 250, 200, 100, 121, 1027, 180, 69, 494, 826, 358, 192, 153, 275, 242, 220, 824, 180, 170, 198, 300, 549, 143, 302, 150, 126, 160, 350, 84, 270, 162, 200, 230, 357, 170, 280, 688, 195, 300, 549, 120, 127, 250, 269, 384, 1000, 236, 131, 148, 120, 48, 243, 524, 48, 131, 500, 165, 501, 500, 169, 138, 196, 450, 358, 400, 204, 381, 250, 119, 226, 200, 150, 150, 164, 359, 229, 229, 250, 240, 132, 129, 826, 154, 275, 148, 99, 190, 66, 329, 600, 130, 229, 396, 138, 604, 716, 714, 80, 212, 220, 184, 98, 441, 90, 214, 80, 200, 1101, 200, 91, 120, 65, 65, 131, 417, 294, 396, 358, 99, 200, 610, 250, 1098, 1093, 156, 80, 184, 179, 169, 200, 190, 191, 79, 247, 180, 472, 165, 600, 425, 217, 100, 250, 347, 400, 150, 180, 980, 686, 144, 99, 72, 180, 200, 659, 286, 150, 900, 800, 108, 800, 440, 165, 150, 80, 659, 248, 180, 86, 160, 290, 170, 206, 180, 330, 70, 357, 54, 290, 439, 357, 130, 350, 517, 220, 800, 604, 250, 200, 180, 300, 458, 150, 220, 549, 250, 357, 120, 140, 164, 661, 379, 100, 190, 90, 299, 115, 170, 800, 600, 259, 873, 250, 160, 1101, 60, 450, 200, 500, 206, 98, 900, 436, 130, 500, 635, 250, 220, 60, 417, 600, 240, 120, 120, 120, 200, 250, 200, 150, 490, 155, 384, 549, 900, 873, 873, 876, 239, 300, 200, 275, 133, 138, 275, 290, 282, 400, 129, 364, 275, 384, 128, 351, 300, 826, 716, 400, 220, 821, 400, 54, 300, 400, 528, 100, 229, 340, 180, 400, 240, 220, 200, 350, 700, 364, 439, 120, 406, 79, 341, 700, 108, 161, 420, 275, 714, 200, 165, 416, 230, 249, 110, 1098, 275, 93, 655, 659, 110, 80, 321, 380, 375, 220, 72, 66, 69, 64, 107, 422, 300, 571, 275, 588, 154, 145, 250, 500, 300, 189, 300, 95, 180, 150, 120, 165, 600, 544, 499, 100, 142, 95, 150, 192, 200, 254, 336, 209, 160, 379, 203, 303, 120, 90, 280, 327, 800, 659, 280, 283, 250, 191, 400, 379, 991, 263, 250, 215, 169, 1000, 423, 450, 157, 159, 169, 550, 439, 439, 714, 384, 250, 149, 121, 200, 335, 143, 560, 496, 373, 128, 215, 81, 384, 168, 599, 93, 159, 180, 180, 441, 496, 465, 200, 620, 1071, 88, 100, 198, 96, 170, 150, 220, 193, 275, 193, 64, 299, 119, 116, 150, 89, 235, 180, 100, 826, 250, 88, 200, 110, 193, 200, 788, 211, 200, 350, 1000, 549, 329, 220, 160, 83, 200, 150, 293, 101, 450, 149, 520, 146, 115, 606, 400, 249, 229, 243, 659, 203, 250, 216, 240, 73, 60, 110, 390, 250, 100, 180, 280, 180, 230, 124, 769, 226, 1000, 255, 300, 315, 600, 297, 406, 250, 250, 700, 441, 203, 522, 321, 96, 150, 550, 384, 346, 217, 80, 471, 480, 350, 327, 468, 675, 1000, 467, 160, 79, 299, 220, 1093, 90, 700, 400, 131, 100, 100, 100, 65, 991, 1093, 228, 210, 200, 220, 330, 784, 200, 131, 320, 55, 500, 1090, 190, 145, 905, 826, 90, 588, 250, 300, 187, 223, 149, 60, 39, 110, 131, 409, 507, 1076, 262, 468, 230, 330, 196, 110, 206, 165, 159, 39, 439, 250, 441, 100, 439, 150, 220, 150, 448, 171, 314,  ...

# %%
df_adj_price = df[(df.price<1114) & (df.price>9)]

# %%
fig = px.bar(df_adj_price.groupby('neighbourhood_cleansed').median()['price'].nlargest(10), 
             orientation='h', 
             title="Top 10 neighbourhoods by highest prices",
            template='simple_white')
fig.update_yaxes(categoryorder='total ascending')
fig.update_layout(showlegend=False)
# Out:
# <div>                            <div id="0e4c6e14-fa65-4f0e-b654-9b529ad2abb6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0e4c6e14-fa65-4f0e-b654-9b529ad2abb6")) {                    Plotly.newPlot(                        "0e4c6e14-fa65-4f0e-b654-9b529ad2abb6",                        [{"alignmentgroup": "True", "hovertemplate": "variable=price<br>value=%{x}<br>neighbourhood_cleansed=%{y}<extra></extra>", "legendgroup": "price", "marker": {"color": "#1F77B4"}, "name": "price", "offsetgroup": "price", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [661.0, 650.0, 560.0, 549.0, 520.0, 505.0, 500.5, 449.5, 441.0, 391.0], "xaxis": "x", "y": ["Grumari", "Osvaldo Cruz", "Manguinhos", "Gard\u00eania Azul", "Complexo do Alem\u00e3o", "Jacar\u00e9", "Inhoa\u00edba", "Anchieta", "Paci\u00eancia", "Pavuna"], "yaxis": "y"}],                        {"barmode": "relative", "legend": {"title": {"text": "variable"}, "tracegroupgap": 0}, "showlegend": false, "template": {"data": {"bar": [{"error_x": {"color": "rgb(36,36,36)"}, "error_y": {"color": "rgb(36,36,36)"}, "marker": {"line": {"color": "white", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "white", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "rgb(36,36,36)", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "rgb(36,36,36)"}, "baxis": {"endlinecolor": "rgb(36,36,36)", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "rgb(36,36,36)"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 1, "tickcolor": "rgb(36,36,36)", "ticks": "outside"}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 1, "tickcolor": "rgb(36,36,36)", "ticks": "outside"}, "colorscale": [[0.0, "#440154"], [0.1111111111111111, "#482878"], [0.2222222222222222, "#3e4989"], [0.3333333333333333, "#31688e"], [0.4444444444444444, "#26828e"], [0.5555555555555556, "#1f9e89"], [0.6666666666666666, "#35b779"], [0.7777777777777778, "#6ece58"], [0.8888888888888888, "#b5de2b"], [1.0, "#fde725"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 1, "tickcolor": "rgb(36,36,36)", "ticks": "outside"}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 1, "tickcolor": "rgb(36,36,36)", "ticks": "outside"}, "colorscale": [[0.0, "#440154"], [0.1111111111111111, "#482878"], [0.2222222222222222, "#3e4989"], [0.3333333333333333, "#31688e"], [0.4444444444444444, "#26828e"], [0.5555555555555556, "#1f9e89"], [0.6666666666666666, "#35b779"], [0.7777777777777778, "#6ece58"], [0.8888888888888888, "#b5de2b"], [1.0, "#fde725"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 1, "tickcolor": "rgb(36,36,36)", "ticks": "outside"}, "colorscale": [[0.0, "#440154"], [0.1111111111111111, "#482878"], [0.2222222222222222, "#3e4989"], [0.3333333333333333, "#31688e"], [0.4444444444444444, "#26828e"], [0.5555555555555556, "#1f9e89"], [0.6666666666666666, "#35b779"], [0.7777777777777778, "#6ece58"], [0.8888888888888888, "#b5de2b"], [1.0, "#fde725"]], "type": "heatmapgl"}], "histogram": [{"marker": {"line": {"color": "white", "width": 0.6}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 1, "tickcolor": "rgb(36,36,36)", "ticks": "outside"}, "colorscale": [[0.0, "#440154"], [0.1111111111111111, "#482878"], [0.2222222222222222, "#3e4989"], [0.3333333333333333, "#31688e"], [0.4444444444444444, "#26828e"], [0.5555555555555556, "#1f9e89"], [0.6666666666666666, "#35b779"], [0.7777777777777778, "#6ece58"], [0.8888888888888888, "#b5de2b"], [1.0, "#fde725"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 1, "tickcolor": "rgb( ...
