# %% [markdown]
# ### AirBnb Rio
#
# Installing libs

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.figure_factory as ff
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
# %matplotlib inline

# %% [markdown]
# Reading data

# %%
df = pd.read_csv('./listings.csv')
df.head()
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0  17878  https://www.airbnb.com/rooms/17878  20210321015201   2021-03-25
# 1  24480  https://www.airbnb.com/rooms/24480  20210321015201   2021-03-22
# 2  35636  https://www.airbnb.com/rooms/35636  20210321015201   2021-03-25
# 3  35764  https://www.airbnb.com/rooms/35764  20210321015201   2021-03-25
# 4  41198  https://www.airbnb.com/rooms/41198  20210321015201   2021-03-22
#
#                                                 name  \
# 0  Very Nice 2Br in Copacabana w. balcony, fast WiFi
# 1                   Nice and cozy near Ipanema Beach
# 2                   Cosy flat close to Ipanema beach
# 3     COPACABANA SEA BREEZE  -  RIO - 20 X Superhost
# 4                  Modern 2bed,Top end of Copacabana
#
#                                          description  \
# 0  Discounts for long term stays. <br />- Large b...
# 1  My studio is located in the best  of Ipanema. ...
# ...

# %% [markdown]
# #### Neighbourhood Overview

# %% [markdown]
# 1. Top neighbourhoods in number of properties

# %%
fig = px.bar(df.neighbourhood_cleansed.value_counts().nlargest(10), 
             orientation='h', 
             title="Top 10 neighbourhoods by number of properties",
            template='simple_white')
fig.update_yaxes(categoryorder='total ascending')
fig.update_layout(showlegend=False)
# Out:
# <div>                            <div id="f9466177-a421-4dd5-a804-1e1a6906235f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f9466177-a421-4dd5-a804-1e1a6906235f")) {                    Plotly.newPlot(                        "f9466177-a421-4dd5-a804-1e1a6906235f",                        [{"alignmentgroup": "True", "hovertemplate": "variable=neighbourhood_cleansed<br>value=%{x}<br>index=%{y}<extra></extra>", "legendgroup": "neighbourhood_cleansed", "marker": {"color": "#1F77B4"}, "name": "neighbourhood_cleansed", "offsetgroup": "neighbourhood_cleansed", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [7695, 2710, 2581, 1350, 1204, 1186, 1183, 885, 778, 626], "xaxis": "x", "y": ["Copacabana", "Barra da Tijuca", "
# ...

# %% [markdown]
# 2. Top neighbourhoods by highest prices

# %%
df['price'] = df['price'].str.extract(r'(\d+)')
df['price'] = df['price'].astype('float64').astype('Int64')

# %%
fig = px.histogram(df['price'])
fig.show()
# Out:
# <div>                            <div id="fd46225a-17d0-4530-ade4-b5c26fbe5b3b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fd46225a-17d0-4530-ade4-b5c26fbe5b3b")) {                    Plotly.newPlot(                        "fd46225a-17d0-4530-ade4-b5c26fbe5b3b",                        [{"alignmentgroup": "True", "bingroup": "x", "hovertemplate": "variable=price<br>value=%{x}<br>count=%{y}<extra></extra>", "legendgroup": "price", "marker": {"color": "#636efa"}, "name": "price", "offsetgroup": "price", "orientation": "v", "showlegend": true, "type": "histogram", "x": [200, 307, 275, 120, 494, 1, 110, 540, 150, 1, 3, 140, 333, 1, 180, 145, 215, 230, 183, 401, 784, 65, 100, 194, 110, 163, 264, 826, 146, 100, 179, 157, 390, 224, 496, 329, 197, 190, 
# ...

# %%
fig = px.bar(df.groupby('neighbourhood_cleansed').median()['price'].nlargest(15), 
             orientation='h', 
             title="Top 10 neighbourhoods by highest prices",
            template='simple_white')
fig.update_yaxes(categoryorder='total ascending')
fig.update_layout(showlegend=False)
# Out:
# <div>                            <div id="4d9d4b31-a2fd-4314-84c7-4adce881b128" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4d9d4b31-a2fd-4314-84c7-4adce881b128")) {                    Plotly.newPlot(                        "4d9d4b31-a2fd-4314-84c7-4adce881b128",                        [{"alignmentgroup": "True", "hovertemplate": "variable=price<br>value=%{x}<br>neighbourhood_cleansed=%{y}<extra></extra>", "legendgroup": "price", "marker": {"color": "#1F77B4"}, "name": "price", "offsetgroup": "price", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [661.0, 560.0, 520.0, 505.0, 400.0, 399.5, 330.0, 329.5, 329.0, 327.0, 280.0, 278.0, 263.5, 255.0, 250.0], "xaxis": "x", "y": ["Grumari", "Manguinhos", "Complexo do
# ...
